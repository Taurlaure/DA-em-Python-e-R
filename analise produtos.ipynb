# %%
import pandas as pd
import seaborn as srn
import statistics as sts

# %%
#importar dados
dataset = pd.read_csv("produtos.csv", sep=";")
dataset.head(100)
# Out:
#    SEL  CODBARRA                         DESCRICAO VRCUSTO CUSTO_REPOSICAO  \
# 0    T  7,90E+12       ACHOC PO ITALAC PCTE 1,01KG    7,18            7,18
# 1    T  7,90E+12       ACUCAR CRISTAL CORURIPE 5KG      13           13,13
# 2    T  7,90E+12          ACUCAR CRISTAL DELTA 5KG   11,79           11,79
# 3    T  7,89E+12  AGUA MINERAL CRYSTAL C/GAS 500ML    1,12            1,12
# 4    T  7,89E+12  AGUA MINERAL CRYSTAL S/GAS 500ML    0,87            0,87
# ..  ..       ...                               ...     ...             ...
# 95   T  7,90E+12        DETERGENTE YPE CLEAR 500ML    1,28            1,56
# 96   T  7,90E+12          DETERGENTE YPE CLEAR 5LT   12,11           15,08
# 97   T  7,90E+12         DETERGENTE YPE COCO 500ML    1,22             1,5
# 98   T  7,90E+12        DETERGENTE YPE LIMAO 500ML    1,22             1,5
# 99   T  7,90E+12         DETERGENTE YPE MACA 500ML    1,22             1,5
#
# ...

# %%
dataset.shape
# Out:
# (227, 88)
